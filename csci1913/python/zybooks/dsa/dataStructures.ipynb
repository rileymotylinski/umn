# %% [markdown]
# # Data Structures
# ### ADT - Abstract Data Type
# - not defined by the structure, but rather the operations the user wants to preform
# - usually abstracted in your chosen programming language
# #### Common ADTs
# 1. List
# 2. Dynamic Array
# 3. Stack - can only insert/read from top of stack
# 4. Queue - first in, first out
# 5. Dequeue - inserted, removed from front and back ("double queue")
# 6. Bag - unsorted list
# 7. Set
# 8. Priority Queue - members have priority; higher priority -> moved to front of line
# 9. Dictionary/Map
#
# #### Resizing
# - very expensive
# - must coppy old array into new array, plus some extra memory
# - resizing doubles allocation size (?)
#
# #### Prepending (inserting at front)
# - another expensive operations
# - re: resizing

# %% [markdown]
# ## Linked Lists
# ## Doubly Linked Lists
# ## Binary Trees
# ## Binary Search Trees (BST's)
# ## Queue
# - First in, First out
# - can be arrays or linked lists
# - Bounded vs. Unbounded: the former has `maxLength` while the latter can grow indefinitely
# - `(frontIndex + length) % allocationSize` gets the index at which to queue an item
#
# ## Deque (Double ended queue)
# - exactly what you expect
# ## Stack
# - popping removes from front/top
# ### Arrays
# - `frontIndex`, `length`, `alloccationSize` can loop back around

# %% [markdown]
# # Hash tables
# - finds index via hash function, usually `some_numerical_id` % 10
# ## Collisions
# - sometimes, multiple keys can match the same hash code. This is called a collison
# ### Linear Probing
# - finds next oipen position in hash table to put value
# ### Quadratic probing
# - come crazy formula (Hash + c1 + c2) / L2
# - somehow avoids collisions?
# - c1/c2 are not multipleso f the buckets length
# ### Chaining
# - at each index, store an array of all the values associated to a certain hash code
#
# ### Double Hashing
# - (H1(key) + i*H2(key))% table size
# - all of these methods are essentially trying to minimize collisions
#
# - resizing requires rehashing, but can make access more efficient
# - what is open hashing?
# - what is a load factor?
#
#
# # Stacks + Queues
# - intentionally restrictive
# - limit where you can add and remove elements
# ## Stacks
# - Last-In, First-Out (LIFO)
# - stack of plates
# -
# ## Queues
# - First In, First Out (FIFO)
# - line at an amusment parkf
# ### Graphs
# - adjacency matrix or adjaceny list

# %%
##
